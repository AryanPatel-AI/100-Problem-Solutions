# %% [markdown]
# <a href="https://colab.research.google.com/github/apkglobal777/100-Problem-Statement/blob/main/audiototext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome in google colab')
